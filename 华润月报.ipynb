# %%
import pandas as pd

from wsdata.consts import SPZZ, BUHANLIGAO
from wsdata.models import WinsunDatabase
from wsdata.utils import wan, Month

ws = WinsunDatabase()
m = Month()

def color_of_price(x):
    x = float(x)
    if x <= 2e4:
        return 'background-color: red'
    elif x <= 3e4:
        return 'background-color: green'
    elif x <= 4e4:
        return 'background-color: blue'
    else:
        return 'background-color: purple'

class ShiChang:
    gxj = ws.gxj('trend', 'month', 12, usage=SPZZ, plate=BUHANLIGAO)
    
    
    def __cumsum(self, by, group_by):
        df = ws.query(f'month_{by}').filter(usage=SPZZ, plate=BUHANLIGAO).group(group_by, '面积').df()
        df.面积 = df.面积.astype(float)
        return df
    
    def _stock(self, by):
        def cumsum(table): return self.__cumsum(table, by)
        sale = cumsum('sale') 
        sold = cumsum('sold')
        df = pd.merge(sale, sold, on=by)
        df['面积'] = df.面积_x - df.面积_y
        return df
    
    @property
    def trend_table(self):
        return self.gxj.df_adjusted

    @property
    def trend_argue(self):
        argue = self.gxj.shuoli(0).full_text
        
        stock = self._stock('presaleid').面积.sum()
        sold_speed = self.gxj.df_original.sold.mean()
        sold_cycle = stock / sold_speed
        
        argue += f'截止{m.month}月底全市库存{wan(stock):.0f}万㎡，去化周期{round(sold_cycle,0)}个月（按12个月计算）。'
        return argue
    
    @property
    def trend_average(self):
        df = self.gxj.df_original
        sale = df.sale.mean()
        sold = df.sold.mean()
        print(f'近一年月均供应：{wan(sale):.0f}万㎡', 
              f'近一年月均成交：{wan(sold):.0f}万㎡')
        
    @property
    def __stock_table_detail(self):
        def sale(period):
            df = ws.query('month_sold')\
                .filter(usage=SPZZ, plate=BUHANLIGAO, date_range=[m.before(period-1).date, m.date])\
                .group('面积段', '面积').df()
            df.rename(columns={'面积': f'面积_{period}'}, inplace=True)
            df.set_index('面积段', inplace=True)
            return df

        # 面积段标签
        cut_label = ws.query('month_sold')._cut_label('acreage', [90,120,144,180]).set_index('面积段')

        # 库存
        stock = self._stock('面积段').set_index('面积段')

        # 拼合 面积段、库存、3类去化量，按面积段分组
        df = cut_label.join([stock, sale(3), sale(12), sale(36)])
        
        return df
    
    @property
    def stock_table(self):
        df = self.__stock_table_detail
        df = df.pivot_table(index='acreage', aggfunc=sum)

        # 计算去化速度
        for i in [3,12,36]:
            df[f'速度_{i}'] = df.面积 / df[f'面积_{i}']

        # 调整
        df.面积 = df.面积.apply(wan)
        df = df[['面积','速度_3','速度_12','速度_36']].round(2)
        df.index = [f'{x}㎡' for x in df.index]
        
        return df
    
    @property
    def stock_argue(self):
        df = self.__stock_table_detail
        
        stock = df.面积.sum()
        cycle = [stock / df[f'面积_{i}'].sum() for i in (3,12,36)]
        
        return f'截止本月底库存：{wan(stock):.0f}万㎡'\
               f'   去化周期—按近3个月计算：{cycle[0]:.1f}个月'\
               f'   按近12个月计算：{cycle[1]:.1f}个月'\
               f'   按近36个月计算：{cycle[2]:.1f}个月'
    
    
    @property
    def cross_table(self):
        df = ws.query('month_sold')\
                .filter(usage=SPZZ, plate=BUHANLIGAO, 
                        date_range=[m.date, m.date])\
                .cross(values='件数', margins=True,
                       idx_cols=['tprice', 'acreage'],
                       idx_bins=[100,120,150,200,250,300,350,400,450,500], 
                       cols_bins=[90,120,144,180])
        df = df.fillna(0).astype(int)
        return df.style.background_gradient()
    
    @property
    def rank(self):
        df = ws.rank('month_sold', 1, ['popularizename','板块'], ['面积','件数','金额','均价']).head(10)
        df[['面积','金额']] = (df[['面积','金额']]/[1e4, 1e8]).round(2)
        df.均价 = df.均价.astype(int)
        df = df.replace('江北新区直管区','江北')
        df.set_index('rank', inplace=True)
        df = df.style.applymap(color_of_price,  subset=['均价']).bar(subset=['面积'])
        return df
    
sc =  ShiChang()
# Out:
# d:\Anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:1297: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['8']; using no arguments.
#   (coltype, args))

# %% [markdown]
# #### 走势

# %%
sc.trend_table
# Out:
# d:\Anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:1297: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['8']; using no arguments.
#   (coltype, args))
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sale</th>
#       <th>sold</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>201706</th>
#       <td>90.65</td>
#       <td>56.83</td>
#       <td>25472.0</td>
#     </tr>
#     <tr>
#       <th>201707</th>
#       <td>78.50</td>
#       <td>67.76</td>
#       <td>24709.0</td>
#     </tr>
#     <tr>
#       <th>201708</th>
#       <td>35.19</td>
#       <td>38.25</td>
#       <td>22895.0</td>
#     </tr>
#     <tr>
#       <th>201709</th>
#       <td>23.72</td>
#       <td>76.09</td>
#       <td>27603.0</td>
#     </tr>
#     <tr>
#       <th>201710</th>
#       <td>12.49</td>
#       <td>41.43</td>
#       <td>24024.0</td>
#     </tr>
#     <tr>
#       <th>201711</th>
#       <td>126.97</td>
#       <td>53.42</td>
#       <td>24717.0</td>
#     </tr>
#     <tr>
#       <th>201712</th>
#       <td>132.69</td>
#       <td>89.05</td>
#       <td>26590.0</td>
#     </tr>
#     <tr>
#       <th>201801</th>
#       <td>27.08</td>
#       <td>77.01</td>
#       <td>26728.0</td>
#     </tr>
#     <tr>
#       <th>201802</th>
#       <td>13.84</td>
#       <td>36.70</td>
#       <td>25196.0</td>
#     </tr>
#     <tr>
#       <th>201803</th>
#       <td>18.54</td>
#       <td>29.83</td>
#       <td>24765.0</td>
#     </tr>
#     <tr>
#       <th>201804</th>
#       <td>34.20</td>
#       <td>38.03</td>
#       <td>27839.0</td>
#     </tr>
#     <tr>
#       <th>201805</th>
#       <td>37.88</td>
#       <td>35.62</td>
#       <td>25861.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print(sc.trend_argue)
print(sc.trend_average)
# Out:
# d:\Anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:1297: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['8']; using no arguments.
#   (coltype, args))
# 上市37.88万㎡，环比增长11%。成交35.62万㎡，环比下降6%。成交均价25861元/㎡，环比下降7%。截止5月底全市库存399万㎡，去化周期7.0个月（按12个月计算）。
# 近一年月均供应：53万㎡ 近一年月均成交：53万㎡
# None

# %% [markdown]
# #### 库存

# %%
sc.stock_table
# Out:
# d:\Anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:1297: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['8']; using no arguments.
#   (coltype, args))
#               面积  速度_3  速度_12  速度_36
# 90-㎡       69.52  2.62   0.45   0.08
# 90-120㎡    94.50  3.55   0.52   0.10
# 120-144㎡   81.23  3.46   0.46   0.12
# 144-180㎡   33.49  4.90   0.69   0.18
# 180+㎡     120.48  6.00   1.53   0.27

# %%
sc.stock_argue
# Out:
# d:\Anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:1297: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['8']; using no arguments.
#   (coltype, args))
# '截止本月底库存：399万㎡   去化周期—按近3个月计算：3.9个月   按近12个月计算：0.6个月   按近36个月计算：0.1个月'

# %% [markdown]
# #### 交叉

# %%
sc.cross_table
# Out:
# d:\Anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py:1297: SAWarning: Could not instantiate type <class 'sqlalchemy.sql.sqltypes.INTEGER'> with reflected arguments ['8']; using no arguments.
#   (coltype, args))
# <style  type="text/css" >
#     #T_d056fd08_63d8_11e8_a5c7_64006a30b424row0_col0 {
#             background-color:  #faf3f9;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row0_col1 {
#             background-color:  #fbf3f9;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row0_col3 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row0_col4 {
#             background-color:  #fdf5fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row0_col5 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row1_col0 {
#             background-color:  #faf2f8;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row1_col1 {
#             background-color:  #fbf4f9;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row1_col2 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row1_col3 {
#             background-color:  #fdf5fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row1_col4 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row1_col5 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row2_col0 {
#             background-color:  #f8f1f8;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row2_col1 {
#             background-color:  #fcf4fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row2_col2 {
#             background-color:  #fdf5fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row2_col3 {
#             background-color:  #fef6fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row2_col4 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row2_col5 {
#             background-color:  #fef6fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row3_col0 {
#             background-color:  #d9d8ea;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row3_col1 {
#             background-color:  #f4edf6;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row3_col2 {
#             background-color:  #fbf3f9;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row3_col3 {
#             background-color:  #faf3f9;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row3_col4 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row3_col5 {
#             background-color:  #f2ecf5;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row4_col0 {
#             background-color:  #4c99c5;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row4_col1 {
#             background-color:  #b7c5df;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row4_col2 {
#             background-color:  #fcf4fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row4_col3 {
#             background-color:  #fef6fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row4_col4 {
#             background-color:  #fef6fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row4_col5 {
#             background-color:  #bcc7e1;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row5_col0 {
#             background-color:  #f4edf6;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row5_col1 {
#             background-color:  #8bb2d4;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row5_col2 {
#             background-color:  #ede8f3;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row5_col3 {
#             background-color:  #fdf5fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row5_col4 {
#             background-color:  #fdf5fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row5_col5 {
#             background-color:  #e0deed;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row6_col0 {
#             background-color:  #fdf5fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row6_col1 {
#             background-color:  #fbf4f9;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row6_col2 {
#             background-color:  #bdc8e1;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row6_col3 {
#             background-color:  #f2ecf5;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row6_col4 {
#             background-color:  #fdf5fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row6_col5 {
#             background-color:  #f7f0f7;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row7_col0 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row7_col1 {
#             background-color:  #f9f2f8;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row7_col2 {
#             background-color:  #d9d8ea;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row7_col3 {
#             background-color:  #e5e1ef;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row7_col4 {
#             background-color:  #fef6fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row7_col5 {
#             background-color:  #faf2f8;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row8_col0 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row8_col1 {
#             background-color:  #fef6fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row8_col2 {
#             background-color:  #f1ebf4;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row8_col3 {
#             background-color:  #fbf4f9;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row8_col4 {
#             background-color:  #fcf4fa;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row8_col5 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row9_col0 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row9_col1 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row9_col2 {
#             background-color:  #f0eaf4;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row9_col3 {
#             background-color:  #e2dfee;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row9_col4 {
#             background-color:  #faf2f8;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row9_col5 {
#             background-color:  #fef6fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row10_col0 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row10_col1 {
#             background-color:  #fff7fb;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row10_col2 {
#             background-color:  #f0eaf4;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row10_col3 {
#             background-color:  #7dacd1;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row10_col4 {
#             background-color:  #045788;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row10_col5 {
#             background-color:  #f2ecf5;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row11_col0 {
#             background-color:  #023858;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row11_col1 {
#             background-color:  #023858;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row11_col2 {
#             background-color:  #023858;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row11_col3 {
#             background-color:  #023858;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row11_col4 {
#             background-color:  #023858;
#         }    #T_d056fd08_63d8_11e8_a5c7_64006a30b424row11_col5 {
#             background-color:  #023858;
#         }</style>
# <table id="T_d056fd08_63d8_11e8_a5c7_64006a30b424" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=6>件数</th>
#     </tr>    <tr>
#         <th class="index_name level1" >acreage</th>
#         <th class="col_heading level1 col0" >90-</th>
#         <th class="col_heading level1 col1" >90-120</th>
#         <th class="col_heading level1 col2" >120-144</th>
#         <th class="col_heading level1 col3"

# %% [markdown]
# #### 排行榜

# %%
sc.rank
# Out:
# <style  type="text/css" >
#     #T_087f9328_63e1_11e8_b06c_64006a30b424row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row0_col5 {
#             background-color:  red;
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.1%, transparent 0%);
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row1_col5 {
#             background-color:  green;
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.9%, transparent 0%);
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row2_col5 {
#             background-color:  red;
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.9%, transparent 0%);
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row3_col5 {
#             background-color:  red;
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.0%, transparent 0%);
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row4_col5 {
#             background-color:  red;
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.7%, transparent 0%);
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row5_col5 {
#             background-color:  green;
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.7%, transparent 0%);
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row6_col5 {
#             background-color:  red;
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.7%, transparent 0%);
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row7_col5 {
#             background-color:  green;
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 0%);
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row8_col5 {
#             background-color:  green;
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row9_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_087f9328_63e1_11e8_b06c_64006a30b424row9_col5 {
#             background-color:  green;
#         }</style>
# <table id="T_087f9328_63e1_11e8_b06c_64006a30b424" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >popularizename</th>
#         <th class="col_heading level0 col1" >板块</th>
#         <th class="col_heading level0 col2" >面积</th>
#         <th class="col_heading level0 col3" >件数</th>
#         <th class="col_heading level0 col4" >金额</th>
#         <th class="col_heading level0 col5" >均价</th>
#     </tr>    <tr>
#         <th class="index_name level0" >rank</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_087f9328_63e1_11e8_b06c_64006a30b424level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row0_col0" class="data row0 col0" >南京溧水万达广场</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row0_col1" class="data row0 col1" >溧水</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row0_col2" class="data row0 col2" >6.01</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row0_col3" class="data row0 col3" >537</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row0_col4" class="data row0 col4" >7.06</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row0_col5" class="data row0 col5" >11758</td>
#     </tr>    <tr>
#         <th id="T_087f9328_63e1_11e8_b06c_64006a30b424level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row1_col0" class="data row1 col0" >融侨悦城</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row1_col1" class="data row1 col1" >江宁</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row1_col2" class="data row1 col2" >3.88</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row1_col3" class="data row1 col3" >369</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row1_col4" class="data row1 col4" >8.83</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row1_col5" class="data row1 col5" >22772</td>
#     </tr>    <tr>
#         <th id="T_087f9328_63e1_11e8_b06c_64006a30b424level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row2_col0" class="data row2 col0" >天岳城</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row2_col1" class="data row2 col1" >溧水</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row2_col2" class="data row2 col2" >2.74</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row2_col3" class="data row2 col3" >247</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row2_col4" class="data row2 col4" >2.22</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row2_col5" class="data row2 col5" >8118</td>
#     </tr>    <tr>
#         <th id="T_087f9328_63e1_11e8_b06c_64006a30b424level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row3_col0" class="data row3 col0" >恒大金碧天下</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row3_col1" class="data row3 col1" >溧水</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row3_col2" class="data row3 col2" >2.58</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row3_col3" class="data row3 col3" >188</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row3_col4" class="data row3 col4" >2.02</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row3_col5" class="data row3 col5" >7846</td>
#     </tr>    <tr>
#         <th id="T_087f9328_63e1_11e8_b06c_64006a30b424level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row4_col0" class="data row4 col0" >万达茂</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row4_col1" class="data row4 col1" >仙林</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row4_col2" class="data row4 col2" >2.18</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row4_col3" class="data row4 col3" >706</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row4_col4" class="data row4 col4" >3.39</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row4_col5" class="data row4 col5" >15517</td>
#     </tr>    <tr>
#         <th id="T_087f9328_63e1_11e8_b06c_64006a30b424level0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row5_col0" class="data row5 col0" >世茂荣里</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row5_col1" class="data row5 col1" >江北</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row5_col2" class="data row5 col2" >2.13</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row5_col3" class="data row5 col3" >222</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row5_col4" class="data row5 col4" >5.14</td>
#         <td id="T_087f9328_63e1_11e8_b06c_64006a30b424row5_col5" class="data row5 col5"

# %% [markdown]
# #### 竞品

# %%
projects = ['华润国际社区','世茂荣里','中建国熙台','三金鑫宁府','雅居乐滨江国际','观山悦']

def get_one(prj):
    df = ws.query('month_sold')\
            .filter(popname=prj, date_range=[m.date, m.date], usage=SPZZ)\
            .group('popularizename', ['件数','面积','金额']).df()
    df['均价'] = df.金额/df.面积
    
    if len(df):
        print(f"{prj}签约{df.at[0,'件数']}套, 均价{wan(df.at[0,'均价']):.1f}元/㎡。")

    return df
    
df = pd.concat((get_one(x) for x in projects[:-1]), ignore_index=True)
df[['popularizename','件数','均价']].style.format({'均价':'{:.0f}'})
# Out:
# 华润国际社区签约63套, 均价3.0元/㎡。
# 世茂荣里签约222套, 均价2.4元/㎡。
# 中建国熙台签约1套, 均价3.3元/㎡。
# 三金鑫宁府签约11套, 均价2.6元/㎡。
# 雅居乐滨江国际签约40套, 均价2.6元/㎡。
# <style  type="text/css" >
# </style>
# <table id="T_40dab9c8_63f2_11e8_90ae_64006a30b424" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >popularizename</th>
#         <th class="col_heading level0 col1" >件数</th>
#         <th class="col_heading level0 col2" >均价</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_40dab9c8_63f2_11e8_90ae_64006a30b424level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row0_col0" class="data row0 col0" >华润国际社区</td>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row0_col1" class="data row0 col1" >63</td>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row0_col2" class="data row0 col2" >29638</td>
#     </tr>    <tr>
#         <th id="T_40dab9c8_63f2_11e8_90ae_64006a30b424level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row1_col0" class="data row1 col0" >世茂荣里</td>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row1_col1" class="data row1 col1" >222</td>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row1_col2" class="data row1 col2" >24107</td>
#     </tr>    <tr>
#         <th id="T_40dab9c8_63f2_11e8_90ae_64006a30b424level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row2_col0" class="data row2 col0" >中建国熙台</td>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row2_col1" class="data row2 col1" >1</td>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row2_col2" class="data row2 col2" >32788</td>
#     </tr>    <tr>
#         <th id="T_40dab9c8_63f2_11e8_90ae_64006a30b424level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row3_col0" class="data row3 col0" >三金鑫宁府</td>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row3_col1" class="data row3 col1" >11</td>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row3_col2" class="data row3 col2" >25961</td>
#     </tr>    <tr>
#         <th id="T_40dab9c8_63f2_11e8_90ae_64006a30b424level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row4_col0" class="data row4 col0" >雅居乐滨江国际</td>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row4_col1" class="data row4 col1" >40</td>
#         <td id="T_40dab9c8_63f2_11e8_90ae_64006a30b424row4_col2" class="data row4 col2" >26511</td>
#     </tr></tbody>
# </table>

# %%
prj = projects[-1]
df = ws.query('month_sold')\
        .filter(popname=prj, date_range=[m.date, m.date], usage=SPZZ)\
        .group(['popularizename','功能'], ['件数','面积','金额']).df()
df['均价'] = df.金额/df.面积

for idx, row in df.iterrows():
    print(f"{row.功能}{row.件数}套, 均价{wan(row.均价):.1f}元/㎡。")

df[['popularizename','件数','均价']].style.format({'均价':'{:.0f}'})
# Out:
# 多层住宅1套, 均价2.8元/㎡。
# 小高层住宅10套, 均价2.5元/㎡。
# <style  type="text/css" >
# </style>
# <table id="T_170ac9cc_63f2_11e8_8e98_64006a30b424" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >popularizename</th>
#         <th class="col_heading level0 col1" >件数</th>
#         <th class="col_heading level0 col2" >均价</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_170ac9cc_63f2_11e8_8e98_64006a30b424level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_170ac9cc_63f2_11e8_8e98_64006a30b424row0_col0" class="data row0 col0" >观山悦</td>
#         <td id="T_170ac9cc_63f2_11e8_8e98_64006a30b424row0_col1" class="data row0 col1" >1</td>
#         <td id="T_170ac9cc_63f2_11e8_8e98_64006a30b424row0_col2" class="data row0 col2" >28386</td>
#     </tr>    <tr>
#         <th id="T_170ac9cc_63f2_11e8_8e98_64006a30b424level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_170ac9cc_63f2_11e8_8e98_64006a30b424row1_col0" class="data row1 col0" >观山悦</td>
#         <td id="T_170ac9cc_63f2_11e8_8e98_64006a30b424row1_col1" class="data row1 col1" >10</td>
#         <td id="T_170ac9cc_63f2_11e8_8e98_64006a30b424row1_col2" class="data row1 col2" >25089</td>
#     </tr></tbody>
# </table>
